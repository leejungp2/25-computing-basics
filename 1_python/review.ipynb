# %%
# 함수 정의 기본
def convert_to_f(celsius):
    return celcius * 9/5+32

# %%
def convert_to_c(fahrenheit):
    return (fahrenheit - 32) * 5/9
# Out:
# Wrong

# %%
# review
def P1(input_list: list[int]) -> set:
    # 리스트 내에서 두 번 이상 반환하는 원소만 모아서 set으로 반환
    
    # 우선 set을 선언
    output_set = set()
    input_set = set(input_list) # 리스트 내에서 중복되는 원소들이 없어짐
