# %% [markdown]
# 몫과 나머지

# %%
def my_devide(num1: int, num2: int) -> None:
    quotient = num1 // num2 # 함수 안에서 정의된 variable은 함수 안에서만 작동함
    remainder = num1 % num2
    return quotient, remainder

# %%
def my_devide(num1: int, num2: int) -> None:
    quotient, remainder = divmod(num1, num2)
    return quotient, remainder

# %%
def my_devide(num1: int, num2: int) -> None:
    quotient = int(num1 / num2)
    remainder = num1 - num2*quotient
    return quotient, remainder

# %%
num1 = 6
num2 = 4

# %%
my_devide(num1, num2)
# Out:
# (1, 2)

# %% [markdown]
# n각형 대각선 개수

# %%
# 대각선 개수 식: n(n-3) / 2
def my_diagonal(num1: int) -> None:
    diagonal = int(num1 * (num1-3)/2)
    return diagonal

# %%
# 바로 정수 나눗셈으로 표현해도 ok
def my_diagonal2(num1: int) -> None:
    diagonal = num1 * (num1-3) // 2
    return diagonal

# %%
num1 = 5
my_diagonal(num1)
# Out:
# 5

# %%
my_diagonal2(num1)
# Out:
# 5

# %% [markdown]
# 간단 퀴즈

# %%
# quiz 1
false or True and not False
# 파이썬에서 false는 앞에가 대문자로 정의 되어야 함.
# not False = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # quiz
# ----> 2 false or True and not False
#
# NameError: name 'false' is not defined

# %% [markdown]
# ### String

# %%
"30" * 0
# Out:
# ''

# %%
"30" * 3
# Out:
# '303030'

# %%
"-" * 20
# Out:
# '--------------------'

# %%
"30" + '20'
# Out:
# '3020'

# %%
if len('30*0') == '300'.count("30"): # count는 문자열에서만 사용 가능
    print('Right')
else:
    print("Wrong")
# Out:
# Wrong

# %%
a = input() # print와 input은 출력 방향이 다름

# %%
a
# Out:
# 'My name is jung'

# %%
b = input("What is your name? :")

# %%
b
# Out:
# 'My name is jung'

# %% [markdown]
# ### Control Structures
# 아스키코드 상에서의 대소관계 비교
# - boolean type
# - if-else
# - "in" operator

# %%
0 == False
# Out:
# True

# %%
"0" == False
# Out:
# False

# %% [markdown]
# ### Task
# - Referring to a beef temperature chart.
# - input: internal_temperature (ex. 50도)
# - return: roasted degree (Rare, Medium rare, Medium, Well done)
#
# <참고 사항>
# - Rare: 45-47
# - Medium rare: 50-52
# - Medium: 55-60
# - Well done: 64-70
#
# cf) 49도면 어떻게 반환해야 하지?

# %%
a = input("What is the internal temperature?")

# 조건문을 반드시 함수 안에 넣을 것...
if 45<=a<48

# %%
# 답지
def roasting (internal_temperature: int) -> str:
    if 45<= temp <= 47: 
        return "Rare"
    else:
        roasted = "Undefined"
    return roasted

# 이렇게 할꺼면 처음에 roasted = "undefined" 같이 초기 조건을 assign 해야함

# %%
## 교수님 답지
def beef_cook(temp):
    if temp >= 45 and temp<=47:
        return "Rare"
    elif temp >= 50 and temp <=52:
        return "Medium Rare"
    elif temp >= 55 and temp <= 57:
        return "Medium"
    elif temp >=64 and temp<=70:
        return "Well Done"
    else:
        return "애매모호"
# -> 위의 예시보다, 이렇게 바로 return을 하도록 하는 게 더 좋은 예시

# %% [markdown]
# ### split()
# - Exercise: Split first name and last name

# %%
"abcdefgh".split()
# Out:
# ['abcdefgh']

# %%
"ab cdef gh".split()
# Out:
# ['ab', 'cdef', 'gh']

# %%
"ab\cdef\ngh".split() # 백슬래시 하나를 문자열에 넣고 싶을 때 \\ 쓰는?
# Out:
# ['ab\\cdef', 'gh']

# %%
"Jung Lee".split("n")
# Out:
# ['Ju', 'g Lee']
